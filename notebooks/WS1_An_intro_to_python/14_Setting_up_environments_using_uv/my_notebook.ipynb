# %%
https://www.youtube.com/watch?v=zgSQr0d5EVg

# %%
# Check if uv is installed or not in the environment using  uv
# install python version 3.13 using uv install python 3.12 and check using uv python list and select pin the desired version using uv python pin 3.12
# Create a new project here using uv init my_project --no-workspace (this creates a new project without considering the upstream workspace, that already contains a uv pyproject.toml file)
# Enter the my_project directory using cd my_project and check the list of files using ls -a (this will show all the files including hidden ones)
# Inspect the pyproject.toml file using cat pyproject.toml (this will show the contents of the file)
# Create a new virtual environment using uv venv (this will create a new virtual environment in the project directory)
# Activate the virtual environment using source .venv/bin/activate (this will activate the virtual environment and change the prompt to indicate that you are now in the virtual environment)
# Check which python is being used using which python (this will show the path to the python executable being used in the virtual environment)
# Select the python environment in notebook, by adding path to the virtual environment's python executable.
# Add dependencies to run this simple notebook to plot sine and cosine functions

# %%
import numpy as np
import matplotlib.pyplot as plt


def plot_sin_cos(duration=10, n_points=1000):
    """Plot sine and cosine signals over time."""
    
    t = np.linspace(0, duration, n_points)
    
    plt.plot(t, np.sin(t), label="sin(t)")
    plt.plot(t, np.cos(t), label="cos(t)")
    
    plt.xlabel("Time [s]")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_sin_cos()
